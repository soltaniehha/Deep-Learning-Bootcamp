# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Second Edition](https://www.manning.com/books/deep-learning-with-python-second-edition?a_aid=keras&a_bid=76564dff). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# This notebook was generated for TensorFlow 2.6.

# %% [markdown]
# ## Beyond text classification: Sequence-to-sequence learning

# %% [markdown]
# ### A machine translation example

# %%
# !wget http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip
# !unzip -q spa-eng.zip
# Out:
# --2023-03-31 21:26:30--  http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.192.128, 209.85.145.128, 172.217.219.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.192.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2638744 (2.5M) [application/zip]
# Saving to: ‘spa-eng.zip’
#
# spa-eng.zip         100%[===================>]   2.52M  --.-KB/s    in 0.009s
#
# 2023-03-31 21:26:30 (278 MB/s) - ‘spa-eng.zip’ saved [2638744/2638744]

# %%
text_file = "spa-eng/spa.txt"
with open(text_file) as f:
    lines = f.read().split("\n")[:-1]
text_pairs = []
for line in lines:
    english, spanish = line.split("\t")
    spanish = "[start] " + spanish + " [end]"
    text_pairs.append((english, spanish))

# %%
import random
print(random.choice(text_pairs))
# Out:
# ("He's the most popular boy in the class.", '[start] Es el chico más popular de la clase. [end]')

# %%
import random
random.shuffle(text_pairs)
num_val_samples = int(0.15 * len(text_pairs))
num_train_samples = len(text_pairs) - 2 * num_val_samples
train_pairs = text_pairs[:num_train_samples]
val_pairs = text_pairs[num_train_samples:num_train_samples + num_val_samples]
test_pairs = text_pairs[num_train_samples + num_val_samples:]

# %% [markdown]
# **Vectorizing the English and Spanish text pairs**

# %%
import tensorflow as tf
import string
import re
from tensorflow.keras import layers

strip_chars = string.punctuation + "¿"
strip_chars = strip_chars.replace("[", "")
strip_chars = strip_chars.replace("]", "")

def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(
        lowercase, f"[{re.escape(strip_chars)}]", "")

vocab_size = 15000
sequence_length = 20

source_vectorization = layers.TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length,
)
target_vectorization = layers.TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length + 1,
    standardize=custom_standardization,
)
train_english_texts = [pair[0] for pair in train_pairs]
train_spanish_texts = [pair[1] for pair in train_pairs]
source_vectorization.adapt(train_english_texts)
target_vectorization.adapt(train_spanish_texts)

# %% [markdown]
# **Preparing datasets for the translation task**

# %%
batch_size = 64

def format_dataset(eng, spa):
    eng = source_vectorization(eng)
    spa = target_vectorization(spa)
    return ({
        "english": eng,
        "spanish": spa[:, :-1],
    }, spa[:, 1:])

def make_dataset(pairs):
    eng_texts, spa_texts = zip(*pairs)
    eng_texts = list(eng_texts)
    spa_texts = list(spa_texts)
    dataset = tf.data.Dataset.from_tensor_slices((eng_texts, spa_texts))
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(format_dataset, num_parallel_calls=4)
    return dataset.shuffle(2048).prefetch(16).cache()

train_ds = make_dataset(train_pairs)
val_ds = make_dataset(val_pairs)

# %%
for inputs, targets in train_ds.take(1):
    print(f"inputs['english'].shape: {inputs['english'].shape}")
    print(f"inputs['spanish'].shape: {inputs['spanish'].shape}")
    print(f"targets.shape: {targets.shape}")
# Out:
# inputs['english'].shape: (64, 20)
# inputs['spanish'].shape: (64, 20)
# targets.shape: (64, 20)

# %% [markdown]
# ### Sequence-to-sequence learning with RNNs

# %% [markdown]
# **GRU-based encoder**

# %%
from tensorflow import keras
from tensorflow.keras import layers

embed_dim = 256
latent_dim = 1024

source = keras.Input(shape=(None,), dtype="int64", name="english")
x = layers.Embedding(vocab_size, embed_dim, mask_zero=True)(source)
encoded_source = layers.Bidirectional(
    layers.GRU(latent_dim), merge_mode="sum")(x)

# %% [markdown]
# **GRU-based decoder and the end-to-end model**

# %%
past_target = keras.Input(shape=(None,), dtype="int64", name="spanish")
x = layers.Embedding(vocab_size, embed_dim, mask_zero=True)(past_target)
decoder_gru = layers.GRU(latent_dim, return_sequences=True)
x = decoder_gru(x, initial_state=encoded_source)
x = layers.Dropout(0.5)(x)
target_next_step = layers.Dense(vocab_size, activation="softmax")(x)
seq2seq_rnn = keras.Model([source, past_target], target_next_step)

# %% [markdown]
# **Training our recurrent sequence-to-sequence model**

# %%
seq2seq_rnn.compile(
    optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"])
seq2seq_rnn.fit(train_ds, epochs=15, validation_data=val_ds)
# Out:
# Epoch 1/15
# 1302/1302 [==============================] - 69s 39ms/step - loss: 4.6886 - accuracy: 0.3179 - val_loss: 3.9131 - val_accuracy: 0.3870
# Epoch 2/15
# 1302/1302 [==============================] - 32s 25ms/step - loss: 3.7265 - accuracy: 0.4159 - val_loss: 3.2569 - val_accuracy: 0.4655
# Epoch 3/15
# 1302/1302 [==============================] - 30s 23ms/step - loss: 3.2111 - accuracy: 0.4753 - val_loss: 2.8734 - val_accuracy: 0.5160
# Epoch 4/15
# 1302/1302 [==============================] - 30s 23ms/step - loss: 2.8535 - accuracy: 0.5171 - val_loss: 2.6225 - val_accuracy: 0.5525
# Epoch 5/15
# 1302/1302 [==============================] - 31s 24ms/step - loss: 2.5805 - accuracy: 0.5503 - val_loss: 2.4434 - val_accuracy: 0.5788
# Epoch 6/15
# 1302/1302 [==============================] - 32s 24ms/step - loss: 2.3573 - accuracy: 0.5790 - val_loss: 2.3198 - val_accuracy: 0.5964
# Epoch 7/15
# 1302/1302 [==============================] - 32s 25ms/step - loss: 2.1708 - accuracy: 0.6026 - val_loss: 2.2225 - val_accuracy: 0.6119
# Epoch 8/15
# 1302/1302 [==============================] - 32s 25ms/step - loss: 2.0123 - accuracy: 0.6231 - val_loss: 2.1532 - val_accuracy: 0.6220
# Epoch 9/15
# 1302/1302 [==============================] - 32s 25ms/step - loss: 1.8769 - accuracy: 0.6411 - val_loss: 2.0957 - val_accuracy: 0.6318
# Epoch 10/15
# 1302/1302 [==============================] - 32s 25ms/step - loss: 1.7570 - accuracy: 0.6573 - val_loss: 2.0542 - val_accuracy: 0.6386
# Epoch 11/15
# 1302/1302 [==============================] - 32s 25ms/step - loss: 1.6511 - accuracy: 0.6717 - val_loss: 2.0145 - val_accuracy: 0.6457
# Epoch 12/15
# 1302/1302 [==============================] - 32s 25ms/step - loss: 1.5575 - accuracy: 0.6848 - val_loss: 1.9907 - val_accuracy: 0.6497
# Epoch 13/15
# 1302/1302 [==============================] - 32s 24ms/step - loss: 1.4751 - accuracy: 0.6969 - val_loss: 1.9709 - val_accuracy: 0.6523
# Epoch 14/15
# 1302/1302 [==============================] - 32s 24ms/step - loss: 1.4059 - accuracy: 0.7071 - val_loss: 1.9541 - val_accuracy: 0.6569
# Epoch 15/15
# 1302/1302 [==============================] - 32s 25ms/step - loss: 1.3444 - accuracy: 0.7157 - val_loss: 1.9388 - val_accuracy: 0.6598

# %% [markdown]
# **Translating new sentences with our RNN encoder and decoder**

# %%
import numpy as np
spa_vocab = target_vectorization.get_vocabulary()
spa_index_lookup = dict(zip(range(len(spa_vocab)), spa_vocab))
max_decoded_sentence_length = 20

def decode_sequence(input_sentence):
    tokenized_input_sentence = source_vectorization([input_sentence])
    decoded_sentence = "[start]"
    for i in range(max_decoded_sentence_length):
        tokenized_target_sentence = target_vectorization([decoded_sentence])
        next_token_predictions = seq2seq_rnn.predict(
            [tokenized_input_sentence, tokenized_target_sentence])
        sampled_token_index = np.argmax(next_token_predictions[0, i, :])
        sampled_token = spa_index_lookup[sampled_token_index]
        decoded_sentence += " " + sampled_token
        if sampled_token == "[end]":
            break
    return decoded_sentence

test_eng_texts = [pair[0] for pair in test_pairs]
for _ in range(20):
    input_sentence = random.choice(test_eng_texts)
    print("-")
    print(input_sentence)
    print(decode_sequence(input_sentence))
# Out:
# -
# I'm immune.
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# [start] soy [UNK] [end]
# -
# Why would Tom care?
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# [start] por qué tom me odia [end]
# -
# It only took us fifteen minutes to complete the job.
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# [start] sólo nos tomó quince minutos para el trabajo [end]
# -
# Please listen to what I have to say.
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# [start] por favor escuche lo que tengo que decir [end]
# -
# The line is busy now. Please hold the line.
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# [start] la [UNK] está ocupada aquí hasta la [UNK] [end]
# -
# Tom uncorked the wine.
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# [start] tom [UNK] el vino [end]
# -
# Do you want us to work late tonight?
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# [start] quieres que trabajar tarde esta noche [end]
# -
# Did Tom buy it?
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# [start] tom lo compró [end]
# -
# We'll be there at 2:30.
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# [start] estaremos ahí a las dos y media [end]
# -
# I'm French.
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# [start] estoy francés [end]
# -
# What surprised me was that Tom didn't know Mary.
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# [start] qué me ha dicho que no le compró tom [end]
# -
# Tom doesn't like Chinese food.
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# [start] a tom no le gusta la comida picante [end]
# -
# There is one problem.
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# [start] hay un problema [end]
# -
# Can you take me there?
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# [start] puedes quedarte allí [end]
# -
# Tom has a bald spot.
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# [start] tom tiene un ojo de nervios [end]
# -
# Pay what you want.
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# [start] haz lo que quieras [end]
# -
# Although he is very old, he is strong.
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# [start] aunque él es muy viejo está él [end]
# -
# Is he breathing?
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# [start] está él está [UNK] [end]
# -
# Tom never said one word.
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# [start] tom nunca dijo una palabra [end]
# -
# She has five older brothers.
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# [start] ella tiene cinco hermanos [end]

# %% [markdown]
# ### Sequence-to-sequence learning with Transformer

# %% [markdown]
# #### The Transformer decoder

# %% [markdown]
# **The `TransformerDecoder`**

# %%
class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim)
        self.attention_2 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim)
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation="relu"),
             layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()
        self.supports_masking = True

    def get_config(self):
        config = super().get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "num_heads": self.num_heads,
            "dense_dim": self.dense_dim,
        })
        return config

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1),
             tf.constant([1, 1], dtype=tf.int32)], axis=0)
        return tf.tile(mask, mult)

    def call(self, inputs, encoder_outputs, mask=None):
        causal_mask = self.get_causal_attention_mask(inputs)
        if mask is not None:
            padding_mask = tf.cast(
                mask[:, tf.newaxis, :], dtype="int32")
            padding_mask = tf.minimum(padding_mask, causal_mask)
        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=causal_mask)
        attention_output_1 = self.layernorm_1(inputs + attention_output_1)
        attention_output_2 = self.attention_2(
            query=attention_output_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
        )
        attention_output_2 = self.layernorm_2(
            attention_output_1 + attention_output_2)
        proj_output = self.dense_proj(attention_output_2)
        return self.layernorm_3(attention_output_2 + proj_output)

# %% [markdown]
# #### Putting it all together: A Transformer for machine translation

# %% [markdown]
# **PositionalEmbedding layer**

# %%
class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, input_dim, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=input_dim, output_dim=output_dim)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim)
        self.sequence_length = sequence_length
        self.input_dim = input_dim
        self.output_dim = output_dim

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)

    def get_config(self):
        config = super(PositionalEmbedding, self).get_config()
        config.update({
            "output_dim": self.output_dim,
            "sequence_length": self.sequence_length,
            "input_dim": self.input_dim,
        })
        return config

# %% [markdown]
# **End-to-end Transformer**

# %%
class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim)
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation="relu"),
             layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()

    def call(self, inputs, mask=None):
        if mask is not None:
            mask = mask[:, tf.newaxis, :]
        attention_output = self.attention(
            inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

    def get_config(self):
        config = super().get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "num_heads": self.num_heads,
            "dense_dim": self.dense_dim,
        })
        return config

# %%
embed_dim = 256
dense_dim = 2048
num_heads = 8

encoder_inputs = keras.Input(shape=(None,), dtype="int64", name="english")
x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(encoder_inputs)
encoder_outputs = TransformerEncoder(embed_dim, dense_dim, num_heads)(x)

decoder_inputs = keras.Input(shape=(None,), dtype="int64", name="spanish")
x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(decoder_inputs)
x = TransformerDecoder(embed_dim, dense_dim, num_heads)(x, encoder_outputs)
x = layers.Dropout(0.5)(x)
decoder_outputs = layers.Dense(vocab_size, activation="softmax")(x)
transformer = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %% [markdown]
# **Training the sequence-to-sequence Transformer**

# %%
transformer.compile(
    optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"])
transformer.fit(train_ds, epochs=30, validation_data=val_ds)
# Out:
# Epoch 1/30
# 1302/1302 [==============================] - 54s 35ms/step - loss: 3.7962 - accuracy: 0.4400 - val_loss: 2.8751 - val_accuracy: 0.5375
# Epoch 2/30
# 1302/1302 [==============================] - 31s 24ms/step - loss: 2.8529 - accuracy: 0.5502 - val_loss: 2.5319 - val_accuracy: 0.5903
# Epoch 3/30
# 1302/1302 [==============================] - 31s 23ms/step - loss: 2.5542 - accuracy: 0.5939 - val_loss: 2.3949 - val_accuracy: 0.6103
# Epoch 4/30
# 1302/1302 [==============================] - 31s 23ms/step - loss: 2.3903 - accuracy: 0.6202 - val_loss: 2.3558 - val_accuracy: 0.6207
# Epoch 5/30
# 1302/1302 [==============================] - 31s 24ms/step - loss: 2.2848 - accuracy: 0.6392 - val_loss: 2.3161 - val_accuracy: 0.6284
# Epoch 6/30
# 1302/1302 [==============================] - 31s 23ms/step - loss: 2.2103 - accuracy: 0.6524 - val_loss: 2.3054 - val_accuracy: 0.6369
# Epoch 7/30
# 1302/1302 [==============================] - 31s 23ms/step - loss: 2.1498 - accuracy: 0.6645 - val_loss: 2.2976 - val_accuracy: 0.6439
# Epoch 8/30
# 1302/1302 [==============================] - 31s 24ms/step - loss: 2.0879 - accuracy: 0.6769 - val_loss: 2.2539 - val_accuracy: 0.6495
# Epoch 9/30
# 1302/1302 [==============================] - 30s 23ms/step - loss: 2.0311 - accuracy: 0.6872 - val_loss: 2.2530 - val_accuracy: 0.6549
# Epoch 10/30
# 1302/1302 [==============================] - 31s 23ms/step - loss: 1.9834 - accuracy: 0.6964 - val_loss: 2.2357 - val_accuracy: 0.6567
# Epoch 11/30
# 1302/1302 [==============================] - 31s 23ms/step - loss: 1.9464 - accuracy: 0.7029 - val_loss: 2.2485 - val_accuracy: 0.6608
# Epoch 12/30
# 1302/1302 [==============================] - 30s 23ms/step - loss: 1.9116 - accuracy: 0.7100 - val_loss: 2.2633 - val_accuracy: 0.6628
# Epoch 13/30
# 1302/1302 [==============================] - 30s 23ms/step - loss: 1.8869 - accuracy: 0.7137 - val_loss: 2.2547 - val_accuracy: 0.6636
# Epoch 14/30
# 1302/1302 [==============================] - 30s 23ms/step - loss: 1.8629 - accuracy: 0.7187 - val_loss: 2.2633 - val_accuracy: 0.6644
# Epoch 15/30
# 1302/1302 [==============================] - 30s 23ms/step - loss: 1.8422 - accuracy: 0.7222 - val_loss: 2.2899 - val_accuracy: 0.6629
# Epoch 16/30
# 1302/1302 [==============================] - 30s 23ms/step - loss: 1.8227 - accuracy: 0.7260 - val_loss: 2.2903 - val_accuracy: 0.6645
# Epoch 17/30
# 1302/1302 [==============================] - 31s 24ms/step - loss: 1.8041 - accuracy: 0.7293 - val_loss: 2.3102 - val_accuracy: 0.6681
# Epoch 18/30
# 1302/1302 [==============================] - 31s 24ms/step - loss: 1.7887 - accuracy: 0.7323 - val_loss: 2.2838 - val_accuracy: 0.6714
# Epoch 19/30
# 1302/1302 [==============================] - 31s 24ms/step - loss: 1.7708 - accuracy: 0.7357 - val_loss: 2.3626 - val_accuracy: 0.6649
# Epoch 20/30
# 1302/1302 [==============================] - 31s 23ms/step - loss: 1.7567 - accuracy: 0.7387 - val_loss: 2.3058 - val_accuracy: 0.6693
# Epoch 21/30
# 1302/1302 [==============================] - 31s 23ms/step - loss: 1.7415 - accuracy: 0.7413 - val_loss: 2.3287 - val_accuracy: 0.6644
# Epoch 22/30
# 1302/1302 [==============================] - 31s 23ms/step - loss: 1.7268 - accuracy: 0.7438 - val_loss: 2.3713 - val_accuracy: 0.6650
# Epoch 23/30
# 1302/1302 [==============================] - 31s 24ms/step - loss: 1.7152 - accuracy: 0.7458 - val_loss: 2.3907 - val_accuracy: 0.6647
# Epoch 24/30
# 1302/1302 [==============================] - 31s 23ms/step - loss: 1.7005 - accuracy: 0.7483 - val_loss: 2.3829 - val_accuracy: 0.6692
# Epoch 25/30
# 1302/1302 [==============================] - 31s 24ms/step - loss: 1.6851 - accuracy: 0.7511 - val_loss: 2.3720 - val_accuracy: 0.6672
# Epoch 26/30
# 1302/1302 [==============================] - 31s 23ms/step - loss: 1.6714 - accuracy: 0.7532 - val_loss: 2.4002 - val_accuracy: 0.6671
# Epoch 27/30
# 1302/1302 [==============================] - 31s 23ms/step - loss: 1.6581 - accuracy: 0.7558 - val_loss: 2.3955 - val_accuracy: 0.6692
# Epoch 28/30
# 1302/1302 [==============================] - 31s 24ms/step - loss: 1.6473 - accuracy: 0.7576 - val_loss: 2.4224 - val_accuracy: 0.6680
# Epoch 29/30
# 1302/1302 [==============================] - 31s 23ms/step - loss: 1.6337 - accuracy: 0.7601 - val_loss: 2.4243 - val_accuracy: 0.6676
# Epoch 30/30
# 1302/1302 [==============================] - 31s 24ms/step - loss: 1.6206 - accuracy: 0.7626 - val_loss: 2.4125 - val_accuracy: 0.6689

# %% [markdown]
# **Translating new sentences with our Transformer model**

# %%
import numpy as np
spa_vocab = target_vectorization.get_vocabulary()
spa_index_lookup = dict(zip(range(len(spa_vocab)), spa_vocab))
max_decoded_sentence_length = 20

def decode_sequence(input_sentence):
    tokenized_input_sentence = source_vectorization([input_sentence])
    decoded_sentence = "[start]"
    for i in range(max_decoded_sentence_length):
        tokenized_target_sentence = target_vectorization(
            [decoded_sentence])[:, :-1]
        predictions = transformer(
            [tokenized_input_sentence, tokenized_target_sentence])
        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = spa_index_lookup[sampled_token_index]
        decoded_sentence += " " + sampled_token
        if sampled_token == "[end]":
            break
    return decoded_sentence

test_eng_texts = [pair[0] for pair in test_pairs]
for _ in range(20):
    input_sentence = random.choice(test_eng_texts)
    print("-")
    print(input_sentence)
    print(decode_sequence(input_sentence))
# Out:
# -
# Oh, no! My house is on fire!
# [start] rosa no es mi casa en fuego [end]
# -
# Thanks for asking.
# [start] gracias por pedirle [end]
# -
# I spent the whole week in Boston.
# [start] me hice toda la semana en boston [end]
# -
# Are you going to be at this afternoon's meeting?
# [start] vas a llegar a llegar a la tarde [end]
# -
# Do you have any gum?
# [start] tienes un traje [end]
# -
# Tom can't explain it.
# [start] tom no puede negar [end]
# -
# Exercise makes your body strong.
# [start] el oro [UNK] te [UNK] [end]
# -
# That was a tough call.
# [start] fue una [UNK] difícil [end]
# -
# We would rather go to the zoo than to the park.
# [start] prefiero ir al zoo hasta al zoo que [UNK] [end]
# -
# Invite him over to watch a movie.
# [start] [UNK] por más que le haya visto una película [end]
# -
# Tom doesn't want to travel alone.
# [start] tom no quiere comer sola [end]
# -
# Most people consider murder wrong.
# [start] la mayoría de la gente habla con amor [end]
# -
# I have some gifts.
# [start] tengo algunos huevos [end]
# -
# I saw a UFO.
# [start] vi un vaso [end]
# -
# This book deals with China.
# [start] este libro es de china [end]
# -
# Her speech moved the audience.
# [start] su discurso el botón [end]
# -
# I wish it would happen more often.
# [start] ojalá él pudiera pasar más tarde [end]
# -
# Please wish me luck.
# [start] por favor [UNK] suerte [end]
# -
# I have time.
# [start] tengo tiempo [end]
# -
# I stay in Osaka.
# [start] yo me quedaré en osaka [end]

# %% [markdown]
# ## Summary
